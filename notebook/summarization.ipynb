          "经审理查明：2015年以来，在深圳经营地下六合彩的彭建飞（已判决）以支付报酬为条件，雇佣被告人邓建平作为其在娄底的下线。彭建飞提供六合彩网址及管理系统，邓建平负责对下线和上线收、付款，每期将其所发展下线从网上报来的码单进行结算，以银行转账的方式进行彩金结算，起到承上启下的作用。2015年至2017年8月期间，被告人邓建平为牟利，相继发展曾文贤、秦细玉（均已判决）为下线，并接受其及李某、付某、宁某等人的码单，累计接受投注共计7060820元，报给上线彭建飞后，再按中奖情况的对应赔率返回下家中奖款7343420元。\n2019年10月10日，被告人邓建平自动到公安机关投案，到案后如实供述了其上述犯罪事实。\n2020年9月14日，被告人邓建平主动向本院退缴违法所得20000元。"]

# %%
with open('../baseline/stopword.txt') as f:
    stopwords = [i.strip() for i in f.readlines()]
stopwords = set(stopwords + ['.', '（', '）', '-'])

# %%
import math
import nltk
from nltk import PorterStemmer
import re
import jieba

# %%
def sent_tokenize(doc):
    for sent in re.findall(u'[^!?。\.\!\?]+[!?。\.\!\?]?', doc, flags=re.U):
        yield sent

sentences = list(sent_tokenize(doc.strip()))
sentences
# Out:
# ['曲靖市沾益区人民检察院指控，南邓娱乐公司是在缅甸佤邦南邓特区专门开设百家乐、斗牛、字花等项目的赌博公司。',
#  '被告人夏永祥系南邓娱乐公司总经理，被告人韦丰系南邓娱乐公司博彩厅经理。',
#  '2016年12月6日以来，被告人夏永祥、韦丰为拓展南邓娱乐公司赌场客源，通过境内代理组织中国赌客参赌，并通过微信方式接受投注并进行赌资转账、投注单发送等。',
#  '2016年12月6日至2017年2月10日期间，被告人夏永祥、韦丰通过代理杨某1、余某、张某1、杨某2、魏某1、何某1、何某3、冯某、查某、马某等人利用微信、银行卡转账等方式接受上述人员的赌资投注共计736190元，其中被告人夏永祥累计收取赌资485041元，被告人韦丰累计收取赌资251149元，并将上述赌资向南邓娱乐公司赌场“字花摊”进行投注，中奖后，再由被告人夏永祥、韦丰将中奖资金通过微信、银行卡转账给相关上述参赌人员共计187072元。',
#  '上述事实，检察机关提交了物证、书证、证人证言、被告人的供述与辩解、检查、提取、辨认笔录、电子数据等证据证实，指控被告人夏永祥、韦丰的行为触犯《中华人民共和国刑法》第三百零三条第一款的规定，构成赌博罪。',
#  '二被告人系共同犯罪，被告人夏永祥系主犯，被告人韦丰系从犯。',
#  ' 被告人夏永祥、韦丰对指控的事实及罪名均无异议。',
#  ' 辩护人朱勋虎提出被告人夏永祥与韦丰不是共同犯罪，被告人夏永祥具备坦白情节，应对被告人夏永祥判处缓刑。',
#  ' 辩护人俞树学提出被告人韦丰系初犯、从犯，应对被告人韦丰判处缓刑。',
#  ' 经审理查明，南邓娱乐公司是在缅甸佤邦南邓特区专门开设百家乐、斗牛、字花等项目的赌博公司。',
#  '被告人夏永祥系南邓娱乐公司总经理，被告人韦丰系南邓娱乐公司博彩厅经理。',
#  '2016年12月6日以来，被告人夏永祥、韦丰为拓展南邓娱乐公司赌场客源，通过境内代理组织中国赌客参赌，并通过微信方式接受投注并进行赌资转账、投注单发送等。',
# ...

# %%
from collections import OrderedDict


def unique_sentences(sentences):
    sentence_dict = OrderedDict()
    for sent in sentences:
        fingerprint = sent[:15]
        print(fingerprint)
        if fingerprint not in sentence_dict:
            sentence_dict[fingerprint] = sent
    return list(sentence_dict.values())
sentences = unique_sentences(sentences)
sentences
# Out:
# 曲靖市沾益区人民检察院指控，南
# 被告人夏永祥系南邓娱乐公司总经
# 2016年12月6日以来，被告
# 2016年12月6日至2017
# 上述事实，检察机关提交了物证、
# 二被告人系共同犯罪，被告人夏永
#  被告人夏永祥、韦丰对指控的事
#  辩护人朱勋虎提出被告人夏永祥
#  辩护人俞树学提出被告人韦丰系
#  经审理查明，南邓娱乐公司是在
# 被告人夏永祥系南邓娱乐公司总经
# 2016年12月6日以来，被告
# 2016年12月6日至2017
#  上述事实，被告人在开庭审理过
# ['曲靖市沾益区人民检察院指控，南邓娱乐公司是在缅甸佤邦南邓特区专门开设百家乐、斗牛、字花等项目的赌博公司。',
#  '被告人夏永祥系南邓娱乐公司总经理，被告人韦丰系南邓娱乐公司博彩厅经理。',
#  '2016年12月6日以来，被告人夏永祥、韦丰为拓展南邓娱乐公司赌场客源，通过境内代理组织中国赌客参赌，并通过微信方式接受投注并进行赌资转账、投注单发送等。',
#  '2016年12月6日至2017年2月10日期间，被告人夏永祥、韦丰通过代理杨某1、余某、张某1、杨某2、魏某1、何某1、何某3、冯某、查某、马某等人利用微信、银行卡转账等方式接受上述人员的赌资投注共计736190元，其中被告人夏永祥累计收取赌资485041元，被告人韦丰累计收取赌资251149元，并将上述赌资向南邓娱乐公司赌场“字花摊”进行投注，中奖后，再由被告人夏永祥、韦丰将中奖资金通过微信、银行卡转账给相关上述参赌人员共计187072元。',
#  '上述事实，检察机关提交了物证、书证、证人证言、被告人的供述与辩解、检查、提取、辨认笔录、电子数据等证据证实，指控被告人夏永祥、韦丰的行为触犯《中华人民共和国刑法》第三百零三条第一款的规定，构成赌博罪。',
#  '二被告人系共同犯罪，被告人夏永祥系主犯，被告人韦丰系从犯。',
#  ' 被告人夏永祥、韦丰对指控的事实及罪名均无异议。',
#  ' 辩护人朱勋虎提出被告人夏永祥与韦丰不是共同犯罪，被告人夏永祥具备坦白情节，应对被告人夏永祥判处缓刑。',
#  ' 辩护人俞树学提出被告人韦丰系初犯、从犯，应对被告人韦丰判处缓刑。',
#  ' 经审理查明，南邓娱乐公司是在缅甸佤邦南邓特区专门开设百家乐、斗牛、字花等项目的赌博公司。',
# ...

# %%
def _create_frequency_matrix(sentences):
    frequency_matrix = {}
    ps = PorterStemmer()

    for sent in sentences:
        freq_table = {}
        words = jieba.cut(sent, cut_all=False)
        for word in words:
            word = word.lower()
            word = ps.stem(word)
            if word in stopwords:
                continue

            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1

        frequency_matrix[sent[:15]] = freq_table

    return frequency_matrix
frequency_matrix = _create_frequency_matrix(corpus)
frequency_matrix
# Out:
# {' 曲靖市沾益区人民检察院指控，': {' ': 7,
#   '曲靖市': 1,
#   '沾益': 1,
#   '区': 1,
#   '人民检察院': 1,
#   '指控': 3,
#   '南邓': 4,
#   '娱乐': 10,
#   '公司': 12,
#   '缅甸': 2,
#   '佤邦南': 2,
#   '邓': 8,
#   '特区': 2,
#   '专门': 2,
#   '开设': 2,
#   '百家乐': 2,
#   '斗牛': 2,
#   '字花': 2,
#   '项目': 2,
#   '赌博': 2,
#   '被告人': 26,
#   '夏永祥': 17,
#   '系南': 2,
#   '总经理': 2,
#   '韦丰系': 4,
#   '南': 4,
#   '博彩': 2,
#   '厅': 2,
#   '经理': 2,
#   '2016': 4,
#   '年': 6,
#   '12': 4,
#   '月': 6,
#   '日': 4,
#   '韦丰为': 2,
#   '拓展': 2,
#   '赌场': 4,
#   '客源': 2,
#   '境内': 2,
#   '代理': 4,
#   '组织': 2,
#   '中国': 2,
#   '赌客': 2,
#   '参赌': 4,
#   '微信': 7,
#   '方式': 4,
#   '接受': 4,
#   '投注': 6,
#   '进行': 4,
#   '赌资': 10,
#   '转账': 11,
#   '投注单': 2,
#   '发送': 2,
#   '日至': 2,
#   '2017': 2,
#   '10': 2,
#   '期间': 2,
#   '韦丰': 10,
#   '杨某': 9,
#   '余某': 3,
#   '张某': 6,
#   '魏某': 4,
#   '何某': 6,
#   '冯某': 3,
#   '查某': 3,
#   '马某': 3,
#   '利用微': 2,
#   '信': 2,
#   '银行卡': 5,
#   '上述': 6,
#   '人员': 4,
#   '共计': 4,
#   '736190': 2,
#   '元': 8,
# ...

# %%
def _create_tf_matrix(freq_matrix):
    tf_matrix = {}

    for sent, f_table in freq_matrix.items():
        tf_table = {}

        count_words_in_sentence = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sentence

        tf_matrix[sent] = tf_table

    return tf_matrix
tf_matrix = _create_tf_matrix(frequency_matrix)
tf_matrix
# Out:
# {' 曲靖市沾益区人民检察院指控，': {' ': 0.03763440860215054,
#   '曲靖市': 0.005376344086021506,
#   '沾益': 0.005376344086021506,
#   '区': 0.005376344086021506,
#   '人民检察院': 0.005376344086021506,
#   '指控': 0.016129032258064516,
#   '南邓': 0.021505376344086023,
#   '娱乐': 0.053763440860215055,
#   '公司': 0.06451612903225806,
#   '缅甸': 0.010752688172043012,
#   '佤邦南': 0.010752688172043012,
#   '邓': 0.043010752688172046,
#   '特区': 0.010752688172043012,
#   '专门': 0.010752688172043012,
#   '开设': 0.010752688172043012,
#   '百家乐': 0.010752688172043012,
#   '斗牛': 0.010752688172043012,
#   '字花': 0.010752688172043012,
#   '项目': 0.010752688172043012,
#   '赌博': 0.010752688172043012,
#   '被告人': 0.13978494623655913,
#   '夏永祥': 0.0913978494623656,
#   '系南': 0.010752688172043012,
#   '总经理': 0.010752688172043012,
#   '韦丰系': 0.021505376344086023,
#   '南': 0.021505376344086023,
#   '博彩': 0.010752688172043012,
#   '厅': 0.010752688172043012,
#   '经理': 0.010752688172043012,
#   '2016': 0.021505376344086023,
# ...

# %%
def _create_documents_per_words(freq_matrix):
    word_per_doc_table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] += 1
            else:
                word_per_doc_table[word] = 1

    return word_per_doc_table
word_per_doc_table = _create_documents_per_words(frequency_matrix)
word_per_doc_table
# Out:
# {' ': 1,
#  '曲靖市': 1,
#  '沾益': 1,
#  '区': 1,
#  '人民检察院': 1,
#  '指控': 1,
#  '南邓': 1,
#  '娱乐': 1,
#  '公司': 1,
#  '缅甸': 1,
#  '佤邦南': 1,
#  '邓': 2,
#  '特区': 1,
#  '专门': 1,
#  '开设': 1,
#  '百家乐': 1,
#  '斗牛': 1,
#  '字花': 1,
#  '项目': 1,
#  '赌博': 1,
#  '被告人': 2,
#  '夏永祥': 1,
#  '系南': 1,
#  '总经理': 1,
#  '韦丰系': 1,
#  '南': 1,
#  '博彩': 1,
#  '厅': 1,
#  '经理': 1,
#  '2016': 1,
#  '年': 2,
#  '12': 1,
#  '月': 2,
#  '日': 2,
#  '韦丰为': 1,
#  '拓展': 1,
#  '赌场': 1,
#  '客源': 1,
#  '境内': 1,
#  '代理': 1,
#  '组织': 1,
#  '中国': 1,
#  '赌客': 1,
#  '参赌': 1,
#  '微信': 1,
#  '方式': 2,
#  '接受': 2,
#  '投注': 2,
#  '进行': 2,
#  '赌资': 1,
#  '转账': 2,
#  '投注单': 1,
#  '发送': 1,
#  '日至': 1,
#  '2017': 2,
#  '10': 2,
#  '期间': 2,
#  '韦丰': 1,
#  '杨某': 1,
#  '余某': 1,
#  '张某': 1,
#  '魏某': 1,
#  '何某': 1,
#  '冯某': 1,
#  '查某': 1,
#  '马某': 1,
#  '利用微': 1,
#  '信': 1,
#  '银行卡': 1,
#  '上述': 2,
#  '人员': 1,
#  '共计': 2,
#  '736190': 1,
#  '元': 2,
#  '累计': 2,
#  '收取': 1,
#  '485041': 1,
#  '251149': 1,
#  '字花摊': 1,
#  '中奖': 2,
#  '资金': 1,
# ...

# %%
def _create_idf_matrix(freq_matrix, count_doc_per_words, total_documents):
    idf_matrix = {}

    for sent, f_table in freq_matrix.items():
        idf_table = {}

        for word in f_table.keys():
            idf_table[word] = math.log10(total_documents / float(count_doc_per_words[word]))

        idf_matrix[sent] = idf_table

    return idf_matrix
idf_matrix = _create_idf_matrix(tf_matrix, word_per_doc_table, len(sentences))
idf_matrix
# Out:
# {' 曲靖市沾益区人民检察院指控，': {' ': 1.041392685158225,
#   '曲靖市': 1.041392685158225,
#   '沾益': 1.041392685158225,
#   '区': 1.041392685158225,
#   '人民检察院': 1.041392685158225,
#   '指控': 1.041392685158225,
#   '南邓': 1.041392685158225,
#   '娱乐': 1.041392685158225,
#   '公司': 1.041392685158225,
#   '缅甸': 1.041392685158225,
#   '佤邦南': 1.041392685158225,
#   '邓': 0.7403626894942439,
#   '特区': 1.041392685158225,
#   '专门': 1.041392685158225,
#   '开设': 1.041392685158225,
#   '百家乐': 1.041392685158225,
#   '斗牛': 1.041392685158225,
#   '字花': 1.041392685158225,
#   '项目': 1.041392685158225,
#   '赌博': 1.041392685158225,
#   '被告人': 0.7403626894942439,
#   '夏永祥': 1.041392685158225,
#   '系南': 1.041392685158225,
#   '总经理': 1.041392685158225,
#   '韦丰系': 1.041392685158225,
#   '南': 1.041392685158225,
#   '博彩': 1.041392685158225,
#   '厅': 1.041392685158225,
#   '经理': 1.041392685158225,
#   '2016': 1.041392685158225,
#   '年': 0.7403626894942439,
#   '12': 1.041392685158225,
#   '月': 0.7403626894942439,
# ...

# %%
def _create_tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}

    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(), idf_matrix.items()):

        tf_idf_table = {}

        for (word1, value1), (word2, value2) in zip(f_table1.items(),
                                                    f_table2.items()):  # here, keys are the same in both the table
            tf_idf_table[word1] = float(value1 * value2)

        tf_idf_matrix[sent1] = tf_idf_table

    return tf_idf_matrix
tf_idf_matrix = _create_tf_idf_matrix(tf_matrix, idf_matrix)
tf_idf_matrix
# Out:
# {' 曲靖市沾益区人民检察院指控，': {' ': 0.03919219782853535,
#   '曲靖市': 0.0055988854040764785,
#   '沾益': 0.0055988854040764785,
#   '区': 0.0055988854040764785,
#   '人民检察院': 0.0055988854040764785,
#   '指控': 0.016796656212229432,
#   '南邓': 0.022395541616305914,
#   '娱乐': 0.05598885404076478,
#   '公司': 0.06718662484891773,
#   '缅甸': 0.011197770808152957,
#   '佤邦南': 0.011197770808152957,
#   '邓': 0.03184355653738684,
#   '特区': 0.011197770808152957,
#   '专门': 0.011197770808152957,
#   '开设': 0.011197770808152957,
#   '百家乐': 0.011197770808152957,
#   '斗牛': 0.011197770808152957,
#   '字花': 0.011197770808152957,
#   '项目': 0.011197770808152957,
#   '赌博': 0.011197770808152957,
#   '被告人': 0.1034915587465072,
#   '夏永祥': 0.09518105186930013,
#   '系南': 0.011197770808152957,
#   '总经理': 0.011197770808152957,
#   '韦丰系': 0.022395541616305914,
#   '南': 0.022395541616305914,
#   '博彩': 0.011197770808152957,
#   '厅': 0.011197770808152957,
#   '经理': 0.011197770808152957,
#   '2016': 0.022395541616305914,
# ...

# %%
def _score_sentences(tf_idf_matrix) -> dict:
    """
    score a sentence by its word's TF
    Basic algorithm: adding the TF frequency of every non-stop word in a sentence divided by total no of words in a sentence.
    :rtype: dict
    """

    sentenceValue = {}

    for sent, f_table in tf_idf_matrix.items():
        total_score_per_sentence = 0

        count_words_in_sentence = len(f_table)
        for word, score in f_table.items():
            total_score_per_sentence += score

        sentenceValue[sent] = total_score_per_sentence / count_words_in_sentence

    return sentenceValue
sentenceValue = _score_sentences(tf_idf_matrix)
sentenceValue
# Out:
# {' 曲靖市沾益区人民检察院指控，': 0.01391630723332057,
#  '经审理查明：2015年以来，在': 0.014761869187673632}

# %%
def _generate_summary(sentences, sentenceValue):
    sentences = sorted(sentences, key=lambda sentence: sentenceValue[sentence[:15]], reverse=True)

    return ''.join(sentences), sentences
summary, sentences = _generate_summary(sentences, sentenceValue)
sentences
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/xgx/search-engine-project/notebook/summarization.ipynb Cell 12' in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2Boctave/home/xgx/search-engine-project/notebook/summarization.ipynb#ch0000012vscode-remote?line=1'>2</a>     sentences = sorted(sentences, key=lambda sentence: sentenceValue[sentence[:15]], reverse=True)
#       <a href='vscode-notebook-cell://ssh-remote%2Boctave/home/xgx/search-engine-project/notebook/summarization.ipynb#ch0000012vscode-remote?line=3'>4</a>     return ''.join(sentences), sentences
# ----> <a href='vscode-notebook-cell://ssh-remote%2Boctave/home/xgx/search-engine-project/notebook/summarization.ipynb#ch0000012vscode-remote?line=4'>5</a> summary, sentences = _generate_summary(sentences, sentenceValue)
# ...

# %%
def score_sentences(sentences):
    pass
